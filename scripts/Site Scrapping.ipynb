# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
#url = "https://www.grubhub.com/restaurant/cast-iron-waffles-9604-longstone-ln-charlotte/1444707"

#html = urlopen(url)
import codecs
htmlfile = './Cast Iron Waffles Delivery - 9604 Longstone Ln Charlotte _ Order Online With Grubhub (12_09_2020 03_06_15).html'
file = codecs.open(htmlfile, "r", "utf-8")


soup = BeautifulSoup(file.read(),'lxml')

# %%
section= soup.find_all('section',{'class':'cb-expansion-panel'})

# %%
data = []
for main in section:
    
    header = main.find('div', {'class': 'menuSection-headerTitle u-flex u-flex-justify-xs--between'}).getText()
    item_div = main.find_all('div',{'class':'s-card-wrapper'})
    
    for menu in item_div:

        div = menu.find('div',{'class':'u-inset-squished-3'})
        name = div.find('a',{'class':'menuItem-name'}).getText()
        descp = div.find('p',{'class':'u-text-secondary'}).getText()
        p = soup.find('span', {'itemprop':'price'}).getText()

        data.append([header,name,descp,p])

# %%
data[20]
# Out:
# ['Latte’s and Coffee',
#  'Iced Latte',
#  'Rich espresso, milk, any flavor!',
#  '$3.99']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data,columns=['categories','menu', 'description', 'price'])

# %%
df
# Out:
#              categories                      menu  \
# 0   Belgian Street Food              Naked Waffle
# 1   Belgian Street Food        Extra Sweet Waffle
# 2   Belgian Street Food             Deluxe Waffle
# 3   Belgian Street Food  Slowberry Cobbler Waffle
# 4   Belgian Street Food     The Lumberjack Waffle
# 5   Belgian Street Food      Cinnamon Roll Waffle
# 6   Belgian Street Food         Sticky Bun Waffle
# 7   Belgian Street Food  Peanut Butter Cup Waffle
# 8   Belgian Street Food            Frozen Waffles
# 9   Belgian Street Food              Bulk Waffles
# 10  Belgian Street Food              Bulk Waffles
# 11  Belgian Street Food      Frozen Dozen Waffles
# 12   Latte’s and Coffee              Fresh Coffee
# 13   Latte’s and Coffee             Premium Latte
# 14   Latte’s and Coffee               Mocha Latte
# 15   Latte’s and Coffee         Caramel Macchiato
# 16   Latte’s and Coffee                Chai Latte
# 17   Latte’s and Coffee                 Americano
# 18   Latte’s and Coffee             Hot Chocolate
# 19   Latte’s and Coffee              Cafe Au Lait
# 20   Latte’s and Coffee                Iced Latte
# 21   Latte’s and Coffee             Specialty Tea
# 22     Specialty Drinks    Traditional Cappuccino
# 23     Specialty Drinks           Double Espresso
# 24     Specialty Drinks     20 oz. Fruit Smoothie
# 25     Specialty Drinks                     Toddy
# 26     Specialty Drinks                Whole Bean
# 27     Specialty Drinks             Specialty Tea
# 28     Specialty Drinks     20 oz. Blended Coffee
#
#                                           description  price
# 0            Belgian street food with powdered sugar.  $3.99
# 1   Choose 1 delicious topping: homemade whipped c...  $3.99
# 2   Nutella, 2 fresh fruits and homemade whipped c...  $3.99
# 3   Slow cooked 4 berry blend topped with fresh wh...  $3.99
# 4   Sweet and salty! Topped with maple buttercream...  $3.99
# 5   The ENVY of all cinnamon rolls! Cinnamon and b...  $3.99
# 6   Candied pecans with sea salt, cinnamon brown s...  $3.99
# 7   Peanut butter mixture, Nutella, fresh whipped ...  $3.99
# 8                           6 pieces. Heat and serve!  $3.99
# 9   6 pieces. 1/2 dozen naked waffles with powdere...  $3.99
# 10  12 pieces. Dozen naked waffles in a bakery box...  $3.99
# 11  Create your own liege waffle buffet to share w...  $3.99
# 12           Fresh roasted blends and single origins.  $3.99
# 13         Rich espresso and micro foam steamed milk.  $3.99
# 14       Latte with dark chocolate and whipped cream.  $3.99
# 15        Latte with caramel sauce and whipped cream.  $3.99
# 16                Spicy oregon chai and steamed milk.  $3.99
# 17                       Rich espresso and hot water.  $3.99
# 18       Dark chocolate, steamed milk, whipped cream.  $3.99
# 19                1/2 fresh coffee, 1/2 steamed milk.  $3.99
# 20                   Rich espresso, milk, any flavor!  $3.99
# 21                        Hand crafted specialty tea.  $3.99
# 22  Authentic 6 oz. cappuccino, 2 oz. espresso, 2 ...  $3.99
# 23  Fresh ground, hand tamped and pulled to perfec...  $3.99
# 24  Choose from a combination of strawberry, banan...  $3.99
# 25  750 ml bottle. Cold pressed espresso concentra...  $3.99
# 26  Always fresh roasted, cast iron waffle blend, ...  $3.99
# 27  1 dozen high quality pyramid mesh tea bags con...  $3.99
# 28           Big train, any flavor and whipped cream.  $3.99
